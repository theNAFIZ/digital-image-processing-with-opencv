# %% [markdown]
# # Annotation

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("images/road-monument.jpg", cv2.IMREAD_COLOR)[:,:,::-1]
plt.imshow(image)

# %% [markdown]
# ### Draw Lines

# %%
img_line = image.copy()
cv2.line(img_line, (200,200), (460,200), (0,0, 255), 3)

plt.imshow(img_line)

# %% [markdown]
# ### Draw Circles

# %% [markdown]
# ### Draw Rectangles

# %% [markdown]
# ### Add Text

# %% [markdown]
# ### All annotations in one image
